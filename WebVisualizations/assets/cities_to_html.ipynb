# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")
df.head()
# Out:
#           City  Cloudiness (%) Country          Date  Humidity (%)  Latitude  \
# 0  new norfolk            40.0      AU  1.586995e+09          63.0    -42.78
# 1    upernavik            61.0      GL  1.586995e+09          89.0     72.79
# 2     hermanus            30.0      ZA  1.586995e+09          81.0    -34.42
# 3       hobart            40.0      AU  1.586995e+09          63.0    -42.88
# 4    cape town            20.0      ZA  1.586995e+09          87.0    -33.93
#
#    Longitude  Max Temperature (F)  Wind Speed (mph)
# 0     147.06                62.60             13.87
# 1     -56.15                15.64              7.18
# 2      19.23                57.99              3.29
# 3     147.33                62.60             13.87
# 4      18.42                60.01              2.24

# %%
s = df.to_html()

print(s)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness (%)</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity (%)</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temperature (F)</th>
#       <th>Wind Speed (mph)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>new norfolk</td>
#       <td>40.0</td>
#       <td>AU</td>
#       <td>1.586995e+09</td>
#       <td>63.0</td>
#       <td>-42.78</td>
#       <td>147.06</td>
#       <td>62.60</td>
#       <td>13.87</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>upernavik</td>
#       <td>61.0</td>
#       <td>GL</td>
#       <td>1.586995e+09</td>
#       <td>89.0</td>
#       <td>72.79</td>
#       <td>-56.15</td>
#       <td>15.64</td>
#       <td>7.18</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>hermanus</td>
#       <td>30.0</td>
# ...
